# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
dataset = pd.read_csv('C:/Users/Swapnil/Desktop/WU/New folder/d.csv');

print(dataset)
 
x = dataset.iloc[:, 0:7].values
y = dataset.iloc[:,7].values
# Out:
#     base target      date  open_bid  close_bid  low_bid  high_bid  \
# 0    EUR    USD  01-12-19   1.10150    1.10150  1.10150   1.10150
# 1    EUR    USD  02-12-19   1.10229    1.10784  1.10029   1.10907
# 2    EUR    USD  03-12-19   1.10782    1.10809  1.10660   1.10934
# 3    EUR    USD  04-12-19   1.10809    1.10775  1.10666   1.11161
# 4    EUR    USD  05-12-19   1.10772    1.11042  1.10772   1.11080
# ..   ...    ...       ...       ...        ...      ...       ...
# 345  EUR    USD  10-11-20   1.18124    1.18127  1.17799   1.18432
# 346  EUR    USD  11-11-20   1.18127    1.17771  1.17454   1.18327
# 347  EUR    USD  12-11-20   1.17771    1.18041  1.17585   1.18231
# 348  EUR    USD  13-11-20   1.18039    1.18310  1.17989   1.18374
# 349  EUR    USD  14-11-20   1.18310    1.18310  1.18310   1.18310
#
#      average_bid  open_ask  close_ask  low_ask  high_ask  average_ask  \
# 0       1.101500   1.10213    1.10213  1.10213   1.10213     1.102130
# ...

# %%
#Encoding the attributes
le1 = LabelEncoder()
le2 = LabelEncoder()
le3 = LabelEncoder()

x[:,0] = le1.fit_transform(x[:,0])
x[:,1] = le2.fit_transform(x[:,1])
x[:,2] = le3.fit_transform(x[:,2])
print(x[0])
print(y)
# Out:
# [0 0 11 1.1015 1.1015 1.1015 1.1015]
# [1.1015    1.1048725 1.1079625 1.1085275 1.109165  1.1077    1.10543
#  1.10543   1.1063175 1.1079    1.1108925 1.112875  1.113715  1.11174
#  1.11174   1.1138025 1.1148975 1.11314   1.1120975 1.1096825 1.10769
#  1.10769   1.108405  1.108505  1.10828   1.10942   1.1138325 1.11713
#  1.11713   1.119115  1.121065  1.12076   1.1193625 1.1157925 1.11548
#  1.11548   1.118125  1.11699   1.1132    1.11058   1.1108925 1.11165
#  1.11165   1.1126825 1.1127525 1.113995  1.11464   1.1113375 1.1089
#  1.1089    1.1091075 1.1093525 1.10855   1.1072775 1.103945  1.10224
#  1.10224   1.1024325 1.1015875 1.10129   1.1021775 1.105945  1.10944
#  1.10944   1.1070675 1.1049825 1.1021025 1.098995  1.0963325 1.09438
#  1.09438   1.092985  1.0910225 1.08944   1.085855  1.0839725 1.08299
#  1.08299   1.0838775 1.0811925 1.0796625 1.0796225 1.0819425 1.08456
#  1.08456   1.083585  1.0863175 1.088135  1.0941075 1.10072   1.10251
# ...

# %%
#Splitting the dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# %%
clf=RandomForestRegressor(n_estimators=100,random_state = 0)
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)

# %%
med=np.median(x_train,axis=0)

y_pred = clf.predict(np.array([[le1.fit_transform(['EUR']),le2.fit_transform(['USD']),le3.fit_transform(['15-11-20']),1.1831, 1.1831, 1.1831, 1.1831]]))

y_pred
# Out:
# array([1.18264321])
